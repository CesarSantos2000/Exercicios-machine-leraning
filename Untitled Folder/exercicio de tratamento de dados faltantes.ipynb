# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
arquivo = pd.read_csv('C:/Users/perei/OneDrive/Documentos/MachineLearnig/dados/2015-building-energy-benchmarking.csv')

# %%
arquivo.head(100)
# Out:
#     OSEBuildingID  DataYear        BuildingType PrimaryPropertyType  \
# 0               1      2015      NonResidential               Hotel
# 1               2      2015      NonResidential               Hotel
# 2               3      2015      NonResidential               Hotel
# 3               5      2015      NonResidential               Hotel
# 4               8      2015      NonResidential               Hotel
# ..            ...       ...                 ...                 ...
# 95            140      2015   SPS-District K-12         K-12 School
# 96            144      2015      NonResidential               Hotel
# 97            145      2015  Nonresidential COS               Other
# 98            147      2015      NonResidential            Hospital
# 99            148      2015   SPS-District K-12         K-12 School
#
#                                     PropertyName  \
# 0                           MAYFLOWER PARK HOTEL
# ...

# %%
dados_percent = ((arquivo.isnull().sum() / len(arquivo)))*100
print(dados_percent)
# Out:
# OSEBuildingID                                                     0.000000
# DataYear                                                          0.000000
# BuildingType                                                      0.000000
# PrimaryPropertyType                                               0.000000
# PropertyName                                                      0.000000
# TaxParcelIdentificationNumber                                     0.059880
# Location                                                          0.000000
# CouncilDistrictCode                                               0.000000
# Neighborhood                                                      0.000000
# YearBuilt                                                         0.000000
# NumberofBuildings                                                 0.000000
# NumberofFloors                                                    0.239521
# ...

# %%
arquivo['ENERGYSTARScore'].fillna(arquivo['ENERGYSTARScore'].median(), inplace=True)

# %%
arquivo.head(50)
# Out:
#     OSEBuildingID  DataYear          BuildingType  \
# 0               1      2015        NonResidential
# 1               2      2015        NonResidential
# 2               3      2015        NonResidential
# 3               5      2015        NonResidential
# 4               8      2015        NonResidential
# 5               9      2015    Nonresidential COS
# 6              10      2015        NonResidential
# 7              11      2015        NonResidential
# 8              12      2015        NonResidential
# 9              13      2015  Multifamily MR (5-9)
# 10             15      2015        NonResidential
# 11             16      2015        NonResidential
# 12             17      2015        NonResidential
# 13             18      2015        NonResidential
# 14             19      2015        NonResidential
# 15             21      2015    Nonresidential COS
# 16             22      2015        NonResidential
# 17             23      2015        NonResidential
# ...
