# %%
import pandas as pd
pd.set_option('display.max_columns', 50)
dados = pd.read_csv('C:/Users/perei/OneDrive/Documentos/MachineLearnig/dados/2015-building-energy-benchmarking.csv')
dados.corr()
# Out:
#                                                     OSEBuildingID  DataYear  \
# OSEBuildingID                                            1.000000       NaN
# DataYear                                                      NaN       NaN
# CouncilDistrictCode                                     -0.092519       NaN
# YearBuilt                                                0.134578       NaN
# NumberofBuildings                                       -0.000676       NaN
# NumberofFloors                                          -0.113519       NaN
# PropertyGFATotal                                        -0.268611       NaN
# PropertyGFAParking                                      -0.179414       NaN
# PropertyGFABuilding(s)                                  -0.261334       NaN
# LargestPropertyUseTypeGFA                               -0.252482       NaN
# SecondLargestPropertyUseTypeGFA                         -0.223600       NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
dados = pd.read_csv('C:/Users/perei/OneDrive/Documentos/MachineLearnig/dados/2015-building-energy-benchmarking.csv')
dados.drop('DataYear', axis=1, inplace=True)
plt.figure(figsize=(10, 10))
sns.heatmap(dados.corr())
plt.show()
